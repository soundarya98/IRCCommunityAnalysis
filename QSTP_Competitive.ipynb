# %%
f=open(r"WhatsApp Chat with QSTP-Competitive Prog..txt", encoding='utf8')

# %%
contents=f.read()
contents
# Out:
# '\ufeff24/04/19, 22:01 - Messages to this group are now secured with end-to-end encryption. Tap for more info.\n24/04/19, 22:01 - +91 99202 61900 created group "QSTP-Competitive Prog."\n24/04/19, 22:01 - +91 99202 61900 added you\n24/04/19, 22:01 - You\'re now an admin\n24/04/19, 22:01 - +91 99202 61900: Hi guys I\'m Kushagra from Quark.\n24/04/19, 22:02 - +91 99202 61900: Pls add the remaining member... Samarth\n24/04/19, 22:06 - Sarthak added Samarth Jain\n24/04/19, 22:06 - Sarthak: Hi\n24/04/19, 22:09 - Rishab Khincha: Hey\n24/04/19, 22:12 - Samarth Jain: Hi\n24/04/19, 22:16 - +91 99202 61900: Can we meet today in anc for like 5 10 mins?\n24/04/19, 22:16 - +91 99202 61900: Sone discussion regarding the course\n24/04/19, 22:16 - +91 99202 61900: Some\n24/04/19, 22:24 - Rishab Khincha: Yeah, I\'m free tonight\n24/04/19, 22:25 - Samarth Jain: Sure\n24/04/19, 22:26 - Sarthak: Cool. 11?\n24/04/19, 22:26 - +91 99202 61900: Ok\n24/04/19, 22:29 - Rishab Khincha: Cool, I\'ll be there\n24/0
# ...

# %%
print(contents)
# Out:
# ﻿24/04/19, 22:01 - Messages to this group are now secured with end-to-end encryption. Tap for more info.
# 24/04/19, 22:01 - +91 99202 61900 created group "QSTP-Competitive Prog."
# 24/04/19, 22:01 - +91 99202 61900 added you
# 24/04/19, 22:01 - You're now an admin
# 24/04/19, 22:01 - +91 99202 61900: Hi guys I'm Kushagra from Quark.
# 24/04/19, 22:02 - +91 99202 61900: Pls add the remaining member... Samarth
# 24/04/19, 22:06 - Sarthak added Samarth Jain
# 24/04/19, 22:06 - Sarthak: Hi
# 24/04/19, 22:09 - Rishab Khincha: Hey
# 24/04/19, 22:12 - Samarth Jain: Hi
# 24/04/19, 22:16 - +91 99202 61900: Can we meet today in anc for like 5 10 mins?
# 24/04/19, 22:16 - +91 99202 61900: Sone discussion regarding the course
# 24/04/19, 22:16 - +91 99202 61900: Some
# 24/04/19, 22:24 - Rishab Khincha: Yeah, I'm free tonight
# 24/04/19, 22:25 - Samarth Jain: Sure
# 24/04/19, 22:26 - Sarthak: Cool. 11?
# 24/04/19, 22:26 - +91 99202 61900: Ok
# ...

# %%
names=[]
contents2=contents.splitlines()
for i in range(len(contents2)):
    s=contents2[i][18:]
    if(s.find(':')!=-1):
        names.append(s[:s.find(':')])

# %%
names
# Out:
# ['+91 99202 61900',
#  '+91 99202 61900',
#  'Sarthak',
#  'Rishab Khincha',
#  'Samarth Jain',
#  '+91 99202 61900',
#  '+91 99202 61900',
#  '+91 99202 61900',
#  'Rishab Khincha',
#  'Samarth Jain',
#  'Sarthak',
#  '+91 99202 61900',
#  'Rishab Khincha',
#  'Rishab Khincha',
#  'Samarth Jain',
#  'Sarthak',
#  '+91 99202 61900',
#  'Sarthak',
#  'Samarth Jain',
#  '+91 99202 61900',
#  'Rishab Khincha',
#  '+91 99202 61900',
#  '+91 99202 61900',
#  '+91 99202 61900',
#  '+91 99202 61900',
#  '+91 99202 61900',
#  '+91 99202 61900',
#  'Rishab Khincha',
#  '+91 99202 61900',
#  '+91 99202 61900',
#  'Rishab Khincha',
#  '+91 99202 61900',
#  '+91 99202 61900',
#  '+91 99202 61900',
#  '+91 99202 61900',
#  '+91 99202 61900',
#  '+91 99202 61900',
#  '+91 99202 61900',
#  'Rishab Khincha',
#  '+91 99202 61900',
#  '+91 99202 61900',
#  'Samarth Jain',
#  'Samarth Jain',
#  '+91 99202 61900',
#  '+91 99202 61900',
#  '+91 99202 61900',
#  'Rishab Khincha',
#  'Rishab Khincha',
# ...

# %%
d={}
for i in range(len(names)):
    d[names[i]]=0
for i in range(len(names)):
    d[names[i]]+=1
    
# d=(sorted(d.items(), key=lambda x: x[1], reverse=True))
# ('Rishab Khincha', '+91 99202 61900', 'Arshdeep Singh', 'Samarth Jain', 'Sarthak', '+91 91317 89215', '+91 91672 46263', '+91 98401 39371')
for key in d:
    if(key in ('Rishab Khincha', '+91 99202 61900', 'Arshdeep Singh', 'Samarth Jain', 'Sarthak', '+91 91317 89215', '+91 91672 46263', '+91 98401 39371')):
        print(key, ":", d[key])
# Out:
# +91 99202 61900 : 45
# Sarthak : 29
# Rishab Khincha : 16
# Samarth Jain : 50
# +91 98401 39371 : 10
# Arshdeep Singh : 2
# +91 91317 89215 : 15
# +91 91672 46263 : 43

# %%
d={}
d2={}
for i in range(len(names)):
    d[names[i]]=0
for i in range(len(names)):
    d[names[i]]+=1
    
# d=(sorted(d.items(), key=lambda x: x[1], reverse=True))
# ('Rishab Khincha', '+91 99202 61900', 'Arshdeep Singh', 'Samarth Jain', 'Sarthak', '+91 91317 89215', '+91 91672 46263', '+91 98401 39371')
for key in d:
    if(key in ('Rishab Khincha', '+91 99202 61900', 'Arshdeep Singh', 'Samarth Jain', 'Sarthak', '+91 91317 89215', '+91 91672 46263', '+91 98401 39371')):
        d2[key]= d[key]
d2=(sorted(d2.items(), key=lambda x: x[1], reverse=True))
d2
# Out:
# [('Samarth Jain', 50),
#  ('+91 99202 61900', 45),
#  ('+91 91672 46263', 43),
#  ('Sarthak', 29),
#  ('Rishab Khincha', 16),
#  ('+91 91317 89215', 15),
#  ('+91 98401 39371', 10),
#  ('Arshdeep Singh', 2)]

# %%
(sorted(d.items(), key=lambda x: x[1], reverse=True))
# Out:
# [('+91 97736 03024', 93),
#  ('+91 88057 11581', 67),
#  ('Samarth Jain', 50),
#  ('+91 99202 61900', 45),
#  ('+91 99969 41700', 44),
#  ('+91 91672 46263', 43),
#  ('+91 70886 72137', 35),
#  ('Sarthak', 29),
#  ('+91 90697 90308', 25),
#  ('+91 74540 97458', 21),
#  ('Rishab Khincha', 16),
#  ('+91 91317 89215', 15),
#  ('+91 90110 98005', 11),
#  ('+91 6290 782 830', 11),
#  ('+91 98401 39371', 10),
#  ('+91 70176 55105', 9),
#  ('+91 97178 99330', 8),
#  ('+91 77678 78935', 7),
#  ('+91 98292 02950', 7),
#  ('+91 95524 89767', 7),
#  ('+91 6354 405 152', 7),
#  ('+91 85459 55830', 7),
#  ('+91 74711 12711', 6),
#  ('+91 70233 79384', 6),
#  ('+91 6387 311 722', 6),
#  ('+91 79751 99044', 6),
#  ('+91 98888 02206', 5),
#  ('+91 78383 77261', 4),
#  ('+91 98203 73878', 4),
#  ('+91 97654 20585', 3),
#  ('+91 95031 83853', 3),
#  ('+91 93701 93941', 3),
#  ('+91 8340 614 212', 2),
#  ('+91 80807 74681', 2),
#  ('+91 83607 58691', 2),
#  ('Arshdeep Singh', 2),
# ...

# %%
time=[]
contents2=contents.splitlines()
for i in range(len(contents2)):
    if(len(contents2[i])>=15):
        if(contents2[i][10].isnumeric()):
            time.append(contents2[i][10:12])

# %%
time
m={}

for val in time:
    if val not in m:
        m[val]=0
    m[val]+=1

# %%
max(m, key=m.get)
# Out:
# '22'

# %%
m
# Out:
# {'22': 154,
#  '23': 88,
#  '04': 4,
#  '19': 44,
#  '01': 27,
#  '03': 1,
#  '21': 31,
#  '11': 25,
#  '00': 47,
#  '09': 9,
#  '10': 27,
#  '13': 21,
#  '20': 48,
#  '08': 14,
#  '14': 32,
#  '17': 28,
#  '18': 31,
#  '15': 17,
#  '16': 8,
#  '07': 3,
#  '12': 27,
#  '06': 3,
#  '02': 3}

# %%
'''New Adjacency List for whatsapp chats'''
names=[]
f=open(r"WhatsApp Chat with QSTP-Competitive Prog..txt", encoding='utf8')
contents=f.read()
contents2=contents.splitlines()
for line in contents2:
    s=line[18:]
    if(s.find(':')!=-1):
        names.append(s[:s.find(':')])

# %%
names
# Out:
# ['+91 99202 61900',
#  '+91 99202 61900',
#  'Sarthak',
#  'Rishab Khincha',
#  'Samarth Jain',
#  '+91 99202 61900',
#  '+91 99202 61900',
#  '+91 99202 61900',
#  'Rishab Khincha',
#  'Samarth Jain',
#  'Sarthak',
#  '+91 99202 61900',
#  'Rishab Khincha',
#  'Rishab Khincha',
#  'Samarth Jain',
#  'Sarthak',
#  '+91 99202 61900',
#  'Sarthak',
#  'Samarth Jain',
#  '+91 99202 61900',
#  'Rishab Khincha',
#  '+91 99202 61900',
#  '+91 99202 61900',
#  '+91 99202 61900',
#  '+91 99202 61900',
#  '+91 99202 61900',
#  '+91 99202 61900',
#  'Rishab Khincha',
#  '+91 99202 61900',
#  '+91 99202 61900',
#  'Rishab Khincha',
#  '+91 99202 61900',
#  '+91 99202 61900',
#  '+91 99202 61900',
#  '+91 99202 61900',
#  '+91 99202 61900',
#  '+91 99202 61900',
#  '+91 99202 61900',
#  'Rishab Khincha',
#  '+91 99202 61900',
#  '+91 99202 61900',
#  'Samarth Jain',
#  'Samarth Jain',
#  '+91 99202 61900',
#  '+91 99202 61900',
#  '+91 99202 61900',
#  'Rishab Khincha',
#  'Rishab Khincha',
# ...

# %%
adj={}
for i in range(2, len(names)-2):
    if names[i] not in adj:
        adj[names[i]]={}
    if (names[i-2] not in adj[names[i]]) and names[i-2]!=names[i]:
        adj[names[i]][names[i-2]]=0
    if names[i-2]!=names[i]:
        adj[names[i]][names[i-2]]+=1
    if (names[i-1] not in adj[names[i]]) and names[i-1]!=names[i]:
        adj[names[i]][names[i-1]]=0
    if names[i-1]!=names[i]:
        adj[names[i]][names[i-1]]+=1
    if (names[i+1] not in adj[names[i]]) and names[i+1]!=names[i]:
        adj[names[i]][names[i+1]]=0
    if names[i+1]!=names[i]:
        adj[names[i]][names[i+1]]+=1
    if (names[i+2] not in adj[names[i]]) and names[i+2]!=names[i]:
        adj[names[i]][names[i+2]]=0
    if names[i+2]!=names[i]:
        adj[names[i]][names[i+2]]+=1

# %%
adj
# Out:
# {'Sarthak': {'+91 99202 61900': 6,
#   'Rishab Khincha': 4,
#   'Samarth Jain': 9,
#   '+91 97654 20585': 1,
#   '+91 98292 02950': 9,
#   '+91 70886 72137': 13,
#   '+91 98919 99866': 1,
#   '+91 97178 99330': 8,
#   '+91 95524 89767': 1,
#   '+91 93701 93941': 4,
#   '+91 85180 76044': 1,
#   '+91 74711 12711': 1,
#   '+91 97736 03024': 4,
#   '+91 98401 39371': 1,
#   '+91 90697 90308': 6,
#   '+91 88604 18506': 2,
#   '+91 74540 97458': 1,
#   '+91 6387 311 722': 1,
#   '+91 99281 77453': 1,
#   '+91 77678 78935': 1,
#   '+91 88057 11581': 3,
#   '+91 70176 55105': 9,
#   'Arshdeep Singh': 1},
#  'Rishab Khincha': {'+91 99202 61900': 27,
#   'Sarthak': 4,
#   'Samarth Jain': 5,
#   '+91 90110 98005': 4,
#   '+91 70886 72137': 5,
#   '+91 97178 99330': 1,
#   '+91 97736 03024': 5,
#   '+91 85459 55830': 2,
#   '+91 98401 39371': 1,
#   '+91 73105 47375': 1,
#   '+91 98203 73878': 1,
#   '+91 88057 11581': 1,
#   '+91 91672 46263': 1},
#  'Samarth Jain': {'Sarthak': 9,
# ...

# %%
edges=[]
import networkx as nx
G=nx.Graph()
for name1 in adj:
    for name2 in adj[name1]:
        if name1 not in G:
            G.add_node(name1)
        if name2 not in G:
            G.add_node(name2)
        ansrow=[name1, name2, adj[name1][name2]]
        edges.append(ansrow)
        G.add_edge(name1, name2, weight=adj[name1][name2])

# %%
nx.draw(G)

# %%
bc=[]
bc=nx.betweenness_centrality(G)

# %%
import operator
sorted(bc.items(), key=operator.itemgetter(1), reverse=True)[0:3]
# Out:
# [('Samarth Jain', 0.1979350669167553),
#  ('+91 97736 03024', 0.15341027195056078),
#  ('+91 88057 11581', 0.13222537291998318)]
